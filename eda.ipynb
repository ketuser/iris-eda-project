# %% [markdown]
# ## Iris Flower EDA: Exploring Species Classification
#
# ###### Author: Anatoly Lunev
# ###### Date: 2025-09-15
# ###### Goal: Explore and visualize the Iris Flower dataset to uncover patterns by species
# ###### Skills practiced: Data cleaning, visualization, SQL querying, and insight summarization
# ###### Tools: Python, Jupyter, Pandas, Matplotlib, Seaborn, pandasql, Git

# %% [markdown]
# #### Step 1. Setting Up the Environment in VS Code
#
# - **VS Code extensions were installe**:
#   - Python (by Microsoft)
#   - Jupyter (for notebooks)
#   - GitHub Pull Requests and Issues
#   - SQLite
#
# - **A new project folder was created**:
#   ```bash
#   mkdir iris_eda_project && cd iris_eda_project
#
# - **Git was initialized**:
#   ```bash
#   git init
#
# - **A virtual environment was created and activated**:
#   ```bash
#   python3 -m venv venv
#   source venv/bin/activate
#
# - **Core packages were installed**:
#   ```bash
#   pip install pandas pandasql numpy matplotlib seaborn scikit-learn jupyter
#
# - **VS Code’s built-in Jupyter support was used by creating eda.ipynb**

# %% [markdown]
# #### Step 2. Fetching and Loading the Dataset

# %%
# Necessary libraries were imported:
import pandas as pd  # For data manipulation
import pandasql as psql # SQL Querying
import numpy as np   # For numerical operations
import matplotlib.pyplot as plt  # For plotting
import seaborn as sns  # For enhanced visualizations

# %%
# The Iris dataset was fetched from UCI (direct URL, no API needed) and loaded into a DataFrame:
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']  # Define headers
df = pd.read_csv(url, header=None, names=column_names)  # Load into DataFrame

# %%
# A quick preview of the data was performed:
print(df.head())      # First 5 rows
print(df.info())      # Data types and non-null counts
print(df.describe())  # Basic statistics
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# ...

# %% [markdown]
# #### Step 3. Data Cleaning and Basic Exploration

# %%
# Duplicates and missing values were checked
print(f"Duplicates: {df.duplicated().sum()}") 
df = df.drop_duplicates() 

# The species column was converted to categorical type:
df['species'] = df['species'].astype('category')

# Basic exploration of nique species was performed:
print(df['species'].value_counts())  

# Outliers were visualized using boxplots:
sns.boxplot(data=df.drop('species', axis=1))  # Visualizing distributions
plt.title('Boxplots for Features')
plt.show()

# Note: Iris has minimal outliers; if any, we can clip or ignore for simplicity
# Out:
# Duplicates: 3
# species
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: count, dtype: int64

# %% [markdown]
# #### Step 4. Visualizations and Insights

# %%
# Relationships between features were visualized using pairplots:
sns.pairplot(df, hue='species')
plt.suptitle('Pairplot of Iris Features by Species')
plt.show()

# Feature correlations were visualized using a heatmap:
numeric_df = df.drop('species', axis=1)
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Key insights were derived:
#
#   - Petal length and width strongly correlate (0.96), useful for classification.
#
#   - Setosa species has smaller petals, making it easier to distinguish.
#
#   - Versicolor and Virginica overlap more, requiring more advanced models for separation.
#
# Pairplot shows clear clusters by species; Heatmap confirms high petal correlations.

# %%
# The notebook was saved and initial changes were committed to Git (/bash):
# !git add .
# !git commit -m "Initial EDA complete"
# Out:
# [main (root-commit) 708573d] Initial EDA complete
#  1 file changed, 304 insertions(+)
#  create mode 100644 eda.ipynb

# %% [markdown]
# ##### Step 5. Adding SQL Querying for Practice

# %%
# pandasql was imported to simulate SQL queries on the DataFrame:
from pandasql import sqldf

# %%
# An example query was executed to calculate average measurements by species:
query = """
SELECT species, AVG(sepal_length) as avg_sepal_length, AVG(petal_length) as avg_petal_length
FROM df
GROUP BY species
"""
result = sqldf(query)
print(result)

# %% [markdown]
# ##### Step 6. Wrapping Up and Preparing for GitHub

# %% [markdown]
# - Project overview was summarized:
#
#     - Simple EDA on Iris dataset using Python, Pandas, and Seaborn.
#     - Demonstrates data loading, cleaning, visualization, and deriving insights.
#
# - Setup instructions were provided:
#
#     - Clone repo: git clone [your-repo-url]
#     - Activate virtual environment: source venv/bin/activate
#     - Run notebook: jupyter notebook eda.ipynb
#
# - Key skills demonstrated:
#
#     - Data analytics with Python
#     - Data visualization
#     - Basic SQL querying
#
# - Insights were summarized from previous steps.

# %%
# Changes were pushed to GitHub (/bash):
# !git remote add origin [url]
# !git push -u origin main
